# %%
from Initialize_and_Train import initialize_and_train
from generate_knapsack_data import Gen_Knapsack_data
import numpy as np
# Out:
# Auto-Sklearn cannot be imported.

# %%
models = ['DYS', 'SPO+', 'BBOpt', 'PertOpt', 'PertOpt-FY']
item_values = np.arange(10,35,5)
num_repeats = 5
results_test_loss = np.zeros((len(models), len(item_values), num_repeats))
results_train_time = np.zeros((len(models), len(item_values), num_repeats))
results_time_till_val_loss = np.zeros((len(models), len(item_values), num_repeats))

# hard code some data parameters
num_knapsack = 2
num_feat = 5
num_data = 1100

# max values
max_epochs = 25
# max time hardcoded to 1 hour

# %%
for item_counter, num_item in enumerate(item_values):
    knapsack_data_dict = {'num_knapsack': num_knapsack,
                          'num_item': num_item,
                          'num_feat': num_feat,
                          'num_data': num_data
                         } 
    
    # Do the thing
    for repeat in range(num_repeats):
        # Generate Data
        knapsack_dict = Gen_Knapsack_data(num_data, num_feat, num_item, num_knapsack)
        for model_counter, model_type in enumerate(models):
            train_time, best_test_loss, time_till_best_test_loss = initialize_and_train(knapsack_dict, knapsack_data_dict, model_type, max_epochs)
            results_test_loss[model_counter, item_counter, repeat] = best_test_loss
            results_train_time[model_counter, item_counter, repeat] = train_time
            results_time_till_val_loss[model_counter, item_counter, repeat] = time_till_best_test_loss
# Out:
# Generating training data for knapsack problem with 2 knapsacks and 10 items
# Restricted license - for non-production use only - expires 2024-10-28
# Optimizing for optDataset...
# 100%|█████████████████████████████████████████| 900/900 [00:00<00:00, 1351.92it/s]
# Optimizing for optDataset...
# 100%|█████████████████████████████████████████| 100/100 [00:00<00:00, 1011.62it/s]
# Optimizing for optDataset...
# 100%|█████████████████████████████████████████| 100/100 [00:00<00:00, 1004.38it/s]
# /Users/danielmckenzie/My-Drive/Research/Fixed_Point_Networks/Diff-Opt-Over-Polytopes-Project/SPO_with_DYS/Knapsack_Testing/dYS_opt_net.py:29: UserWarning: The operator 'aten::linalg_svd' is not currently supported on the MPS backend and will fall back to run on the CPU. This may have performance implications. (Triggered internally at /Users/runner/work/pytorch/pytorch/pytorch/aten/src/ATen/mps/MPSFallback.mm:11.)
#   U, s, VT = torch.linalg.svd(self.A, full_matrices=False)
# Finished building dataset
#
#  Currently training DYS
#
# Initial validation loss is  0.32710927724838257
# epoch:  1 validation loss is  0.2686721980571747 epoch time:  0.2724287509918213
# epoch:  2 validation loss is  0.20193637907505035 epoch time:  0.09565997123718262
# epoch:  3 validation loss is  0.18084371089935303 epoch time:  0.8478257656097412
# epoch:  4 validation loss is  0.17842324078083038 epoch time:  1.658890962600708
# epoch:  5 validation loss is  0.16044260561466217 epoch time:  1.985733985900879
# epoch:  6 validation loss is  0.1390041559934616 epoch time:  2.0360989570617676
# epoch:  7 validation loss is  0.1230982095003128 epoch time:  2.154036045074463
# epoch:  8 validation loss is  0.12240664660930634 epoch time:  2.0871238708496094
# epoch:  9 validation loss is  0.12067773938179016 epoch time:  2.083390235900879
# epoch:  10 validation loss is  0.12067773938179016 epoch time:  1.912700891494751
# epoch:  11 validation loss is  0.1210235208272934 epoch time:  2.0339531898498535
# epoch:  12 validation loss is  0.11998617649078369 epoch time:  2.050213098526001
# epoch:  13 validation loss is  0.1210235208272934 epoch time:  1.774048089981079
# epoch:  14 validation loss is  0.1210235208272934 epoch time:  1.9090471267700195
# epoch:  15 validation loss is  0.12033195793628693 epoch time:  1.9653401374816895
# epoch:  16 validation loss is  0.12033195793628693 epoch time:  2.327501058578491
# epoch:  17 validation loss is  0.11929460614919662 epoch time:  2.33304500579834
# epoch:  18 validation loss is  0.11929460614919662 epoch time:  2.9803378582000732
# epoch:  19 validation loss is  0.11618257313966751 epoch time:  3.002269983291626
# epoch:  20 validation loss is  0.11376210302114487 epoch time:  3.0091357231140137
# epoch:  21 validation loss is  0.11652835458517075 epoch time:  3.0148251056671143
# epoch:  22 validation loss is  0.11479944735765457 epoch time:  2.9891011714935303
# epoch:  23 validation loss is  0.1151452288031578 epoch time:  3.0010268688201904
# epoch:  24 validation loss is  0.1151452288031578 epoch time:  3.0335769653320312
# epoch:  25 validation loss is  0.1151452288031578 epoch time:  3.008862257003784
#
#  Currently training SPO+
#
# Num of cores: 1
# Initial validation loss is  0.32710927724838257
# epoch:  1 validation loss is  0.20816044509410858 epoch time:  0.17902112007141113
# epoch:  2 validation loss is  0.14211618900299072 epoch time:  0.1623859405517578
# epoch:  3 validation loss is  0.1348547786474228 epoch time:  0.16604900360107422
# epoch:  4 validation loss is  0.13381743431091309 epoch time:  0.16629981994628906
# epoch:  5 validation loss is  0.13520056009292603 epoch time:  0.1570427417755127
# epoch:  6 validation loss is  0.13278008997440338 epoch time:  0.16434288024902344
# epoch:  7 validation loss is  0.12828491628170013 epoch time:  0.17238616943359375
# epoch:  8 validation loss is  0.11998617649078369 epoch time:  0.17224621772766113
# epoch:  9 validation loss is  0.11929460614919662 epoch time:  0.17516183853149414
# epoch:  10 validation loss is  0.11756569892168045 epoch time:  0.18281221389770508
# epoch:  11 validation loss is  0.1210235208272934 epoch time:  0.21113801002502441
# epoch:  12 validation loss is  0.11929460614919662 epoch time:  0.22690272331237793
# epoch:  13 validation loss is  0.11583679169416428 epoch time:  0.2600996494293213
# epoch:  14 validation loss is  0.10684647411108017 epoch time:  0.26277875900268555
# epoch:  15 validation loss is  0.10408022254705429 epoch time:  0.28221726417541504
# epoch:  16 validation loss is  0.10269710421562195 epoch time:  0.26378488540649414
# epoch:  17 validation loss is  0.10165975242853165 epoch time:  0.2587888240814209
# epoch:  18 validation loss is  0.10200553387403488 epoch time:  0.24613094329833984
# epoch:  19 validation loss is  0.0982019379734993 epoch time:  0.23134613037109375
# epoch:  20 validation loss is  0.09370678663253784 epoch time:  0.23196911811828613
# epoch:  21 validation loss is  0.09612724930047989 epoch time:  0.22237110137939453
# epoch:  22 validation loss is  0.099239282310009 epoch time:  0.22577714920043945
# epoch:  23 validation loss is  0.09647303074598312 epoch time:  0.23671913146972656
# epoch:  24 validation loss is  0.0971645936369896 epoch time:  0.22246479988098145
# epoch:  25 validation loss is  0.09439834207296371 epoch time:  0.22412705421447754
#
#  Currently training BBOpt
#
# Num of cores: 1
# Initial validation loss is  0.32710927724838257
# epoch:  1 validation loss is  0.2894190847873688 epoch time:  0.3469419479370117
# epoch:  2 validation loss is  0.21161825954914093 epoch time:  0.3837089538574219
# epoch:  3 validation loss is  0.1867220103740692 epoch time:  0.42122411727905273
# epoch:  4 validation loss is  0.14730289578437805 epoch time:  0.4309508800506592
# epoch:  5 validation loss is  0.14349931478500366 epoch time:  0.4668428897857666
# epoch:  6 validation loss is  0.14004148542881012 epoch time:  0.5009350776672363
# epoch:  7 validation loss is  0.1379668116569519 epoch time:  0.5587418079376221
# epoch:  8 validation loss is  0.13658368587493896 epoch time:  0.6224048137664795
# epoch:  9 validation loss is  0.13139696419239044 epoch time:  0.6519861221313477
# epoch:  10 validation loss is  0.13139696419239044 epoch time:  0.6827490329742432
# epoch:  11 validation loss is  0.13278008997440338 epoch time:  0.7634072303771973
# epoch:  12 validation loss is  0.12655602395534515 epoch time:  0.780540943145752
# epoch:  13 validation loss is  0.12621024250984192 epoch time:  0.755500078201294
# epoch:  14 validation loss is  0.12621024250984192 epoch time:  0.7967979907989502
# epoch:  15 validation loss is  0.12275242805480957 epoch time:  0.8131959438323975
# epoch:  16 validation loss is  0.11929460614919662 epoch time:  0.8081028461456299
# epoch:  17 validation loss is  0.11791148036718369 epoch time:  0.7997419834136963
# epoch:  18 validation loss is  0.11964038759469986 epoch time:  0.7949361801147461
# epoch:  19 validation loss is  0.11964038759469986 epoch time:  0.7986040115356445
# epoch:  20 validation loss is  0.11894882470369339 epoch time:  0.8021588325500488
# epoch:  21 validation loss is  0.11964038759469986 epoch time:  0.8205208778381348
# epoch:  22 validation loss is  0.11825726181268692 epoch time:  0.839728832244873
# epoch:  23 validation loss is  0.1220608651638031 epoch time:  0.8216099739074707
# epoch:  24 validation loss is  0.12482710927724838 epoch time:  0.8508889675140381
# epoch:  25 validation loss is  0.12482710927724838 epoch time:  0.8463530540466309
#
#  Currently training PertOpt
#
# Num of cores: 1
# Initial validation loss is  0.32710927724838257
# epoch:  1 validation loss is  0.2686721980571747 epoch time:  2.9034409523010254
# epoch:  2 validation loss is  0.1964038759469986 epoch time:  3.0524849891662598
# epoch:  3 validation loss is  0.15802212059497833 epoch time:  3.361335039138794
# epoch:  4 validation loss is  0.13934992253780365 epoch time:  3.3747100830078125
# epoch:  5 validation loss is  0.1310511827468872 epoch time:  3.6391820907592773
# epoch:  6 validation loss is  0.1310511827468872 epoch time:  3.6253089904785156
# epoch:  7 validation loss is  0.12586446106433868 epoch time:  3.8301830291748047
# epoch:  8 validation loss is  0.12240664660930634 epoch time:  3.8865950107574463
# epoch:  9 validation loss is  0.12136930227279663 epoch time:  3.7082040309906006
# epoch:  10 validation loss is  0.12413554638624191 epoch time:  3.647818088531494
# epoch:  11 validation loss is  0.12240664660930634 epoch time:  3.490989923477173
# epoch:  12 validation loss is  0.12448132783174515 epoch time:  3.493607997894287
# epoch:  13 validation loss is  0.12240664660930634 epoch time:  3.4306318759918213
# epoch:  14 validation loss is  0.12067773938179016 epoch time:  3.291483163833618
# epoch:  15 validation loss is  0.12378976494073868 epoch time:  3.2350971698760986
# epoch:  16 validation loss is  0.12240664660930634 epoch time:  3.1695218086242676
# epoch:  17 validation loss is  0.12517289817333221 epoch time:  3.2827987670898438
# epoch:  18 validation loss is  0.12621024250984192 epoch time:  3.2627100944519043
# epoch:  19 validation loss is  0.12759336829185486 epoch time:  3.234050750732422
# epoch:  20 validation loss is  0.12621024250984192 epoch time:  3.2930591106414795
# epoch:  21 validation loss is  0.12551867961883545 epoch time:  3.0212368965148926
# epoch:  22 validation loss is  0.12551867961883545 epoch time:  3.0718462467193604
# epoch:  23 validation loss is  0.12482710927724838 epoch time:  3.0524439811706543
# epoch:  24 validation loss is  0.1230982095003128 epoch time:  3.1081972122192383
# epoch:  25 validation loss is  0.12378976494073868 epoch time:  3.0891270637512207
#
#  Currently training PertOpt-FY
#
# Num of cores: 1
# Initial validation loss is  0.32710927724838257
# epoch:  1 validation loss is  0.2596818804740906 epoch time:  3.1848628520965576
# epoch:  2 validation loss is  0.1905255913734436 epoch time:  3.6503000259399414
# epoch:  3 validation loss is  0.1538727581501007 epoch time:  4.381920099258423
# epoch:  4 validation loss is  0.1379668116569519 epoch time:  4.963735818862915
# epoch:  5 validation loss is  0.13623790442943573 epoch time:  5.611662149429321
# epoch:  6 validation loss is  0.13727524876594543 epoch time:  6.192134857177734
# epoch:  7 validation loss is  0.14211618900299072 epoch time:  6.570435047149658
# epoch:  8 validation loss is  0.13727524876594543 epoch time:  7.0071821212768555
# epoch:  9 validation loss is  0.13934992253780365 epoch time:  7.323609828948975
# epoch:  10 validation loss is  0.1379668116569519 epoch time:  7.193905353546143
# epoch:  11 validation loss is  0.1369294673204422 epoch time:  7.443112850189209
# epoch:  12 validation loss is  0.13658368587493896 epoch time:  7.790499687194824
# epoch:  13 validation loss is  0.13658368587493896 epoch time:  8.048483848571777
# epoch:  14 validation loss is  0.13658368587493896 epoch time:  8.10131311416626
# epoch:  15 validation loss is  0.13658368587493896 epoch time:  8.290212154388428
# epoch:  16 validation loss is  0.13658368587493896 epoch time:  8.34564995765686
# epoch:  17 validation loss is  0.13658368587493896 epoch time:  8.562521934509277
# epoch:  18 validation loss is  0.13658368587493896 epoch time:  8.759474039077759
# epoch:  19 validation loss is  0.13658368587493896 epoch time:  9.034165382385254
# epoch:  20 validation loss is  0.13658368587493896 epoch time:  9.117314100265503
# epoch:  21 validation loss is  0.13658368587493896 epoch time:  9.223864793777466
# epoch:  22 validation loss is  0.13658368587493896 epoch time:  9.32900619506836
# epoch:  23 validation loss is  0.13658368587493896 epoch time:  9.314803123474121
# epoch:  24 validation loss is  0.13658368587493896 epoch time:  9.42664909362793
# epoch:  25 validation loss is  0.13658368587493896 epoch time:  9.438231229782104
#
#  Currently training DYS
#
# Initial validation loss is  0.32710927724838257
# epoch:  1 validation loss is  0.29011064767837524 epoch time:  0.09301090240478516
# epoch:  2 validation loss is  0.21369294822216034 epoch time:  0.09318304061889648
# epoch:  3 validation loss is  0.20297372341156006 epoch time:  0.3691558837890625
# epoch:  4 validation loss is  0.21680499613285065 epoch time:  1.5808632373809814
# epoch:  5 validation loss is  0.2074688971042633 epoch time:  1.8827991485595703
# epoch:  6 validation loss is  0.1746196448802948 epoch time:  2.0274691581726074
# epoch:  7 validation loss is  0.1438450962305069 epoch time:  2.1718080043792725
# epoch:  8 validation loss is  0.12482710927724838 epoch time:  2.208636999130249
# epoch:  9 validation loss is  0.1230982095003128 epoch time:  1.9672040939331055
# epoch:  10 validation loss is  0.12448132783174515 epoch time:  1.9277927875518799
# epoch:  11 validation loss is  0.12448132783174515 epoch time:  1.884411096572876
# epoch:  12 validation loss is  0.12448132783174515 epoch time:  1.830030918121338
# epoch:  13 validation loss is  0.12517289817333221 epoch time:  1.9188661575317383
# epoch:  14 validation loss is  0.12759336829185486 epoch time:  1.771162748336792
# epoch:  15 validation loss is  0.12932227551937103 epoch time:  1.907418966293335
# epoch:  16 validation loss is  0.12966805696487427 epoch time:  2.1531689167022705
# epoch:  17 validation loss is  0.12621024250984192 epoch time:  3.00901460647583
# epoch:  18 validation loss is  0.1310511827468872 epoch time:  3.028362989425659
# epoch:  19 validation loss is  0.1320885270833969 epoch time:  3.024751901626587
# epoch:  20 validation loss is  0.13174274563789368 epoch time:  3.0245609283447266
# epoch:  21 validation loss is  0.13174274563789368 epoch time:  3.027315855026245
# epoch:  22 validation loss is  0.13139696419239044 epoch time:  3.035839080810547
# epoch:  23 validation loss is  0.13139696419239044 epoch time:  3.041546106338501
# epoch:  24 validation loss is  0.13174274563789368 epoch time:  3.0333378314971924
# epoch:  25 validation loss is  0.13174274563789368 epoch time:  3.0199460983276367
#
#  Currently training SPO+
#
# Num of cores: 1
# Initial validation loss is  0.32710927724838257
# epoch:  1 validation loss is  0.20297372341156006 epoch time:  0.1620643138885498
# epoch:  2 validation loss is  0.1448824405670166 epoch time:  0.15831303596496582
# epoch:  3 validation loss is  0.13450899720191956 epoch time:  0.15865612030029297
# epoch:  4 validation loss is  0.13450899720191956 epoch time:  0.15810799598693848
# epoch:  5 validation loss is  0.13416321575641632 epoch time:  0.15684795379638672
# epoch:  6 validation loss is  0.13278008997440338 epoch time:  0.1666550636291504
# epoch:  7 validation loss is  0.12621024250984192 epoch time:  0.16701626777648926
# epoch:  8 validation loss is  0.11964038759469986 epoch time:  0.17871999740600586
# epoch:  9 validation loss is  0.11791148036718369 epoch time:  0.18506908416748047
# epoch:  10 validation loss is  0.11756569892168045 epoch time:  0.23824191093444824
# epoch:  11 validation loss is  0.1210235208272934 epoch time:  0.24831414222717285
# epoch:  12 validation loss is  0.12171508371829987 epoch time:  0.3014802932739258
# epoch:  13 validation loss is  0.11583679169416428 epoch time:  0.3576622009277344
# epoch:  14 validation loss is  0.10822959989309311 epoch time:  0.39154911041259766
# epoch:  15 validation loss is  0.10788381844758987 epoch time:  0.3775639533996582
# epoch:  16 validation loss is  0.10788381844758987 epoch time:  0.3577280044555664
# epoch:  17 validation loss is  0.10338866710662842 epoch time:  0.3463881015777588
# epoch:  18 validation loss is  0.09785615652799606 epoch time:  0.29590415954589844
# epoch:  19 validation loss is  0.09543568640947342 epoch time:  0.2827267646789551
# epoch:  20 validation loss is  0.09612724930047989 epoch time:  0.27109622955322266
# epoch:  21 validation loss is  0.09578146785497665 epoch time:  0.2742030620574951
# epoch:  22 validation loss is  0.099239282310009 epoch time:  0.26790285110473633
# epoch:  23 validation loss is  0.09301521629095078 epoch time:  0.26924705505371094
# epoch:  24 validation loss is  0.08852005749940872 epoch time:  0.2751808166503906
# epoch:  25 validation loss is  0.09059474617242813 epoch time:  0.2598080635070801
#
#  Currently training BBOpt
#
# Num of cores: 1
# Initial validation loss is  0.32710927724838257
# epoch:  1 validation loss is  0.2814660966396332 epoch time:  0.4127531051635742
# epoch:  2 validation loss is  0.20954357087612152 epoch time:  0.49294209480285645
# epoch:  3 validation loss is  0.1867220103740692 epoch time:  0.5354821681976318
# epoch:  4 validation loss is  0.146957129240036 epoch time:  0.6190991401672363
# epoch:  5 validation loss is  0.14142461121082306 epoch time:  0.6723918914794922
# epoch:  6 validation loss is  0.14004148542881012 epoch time:  0.7836110591888428
# epoch:  7 validation loss is  0.13934992253780365 epoch time:  0.7818171977996826
# epoch:  8 validation loss is  0.13727524876594543 epoch time:  0.7800006866455078
# epoch:  9 validation loss is  0.13139696419239044 epoch time:  0.9046101570129395
# epoch:  10 validation loss is  0.13174274563789368 epoch time:  0.9362099170684814
# epoch:  11 validation loss is  0.1269018054008484 epoch time:  0.9901340007781982
# epoch:  12 validation loss is  0.12482710927724838 epoch time:  1.2192611694335938
# epoch:  13 validation loss is  0.12517289817333221 epoch time:  1.190891981124878
# epoch:  14 validation loss is  0.12448132783174515 epoch time:  1.2944800853729248
# epoch:  15 validation loss is  0.12517289817333221 epoch time:  1.0876379013061523
# epoch:  16 validation loss is  0.12551867961883545 epoch time:  1.051008939743042
# epoch:  17 validation loss is  0.12517289817333221 epoch time:  1.0791330337524414
# epoch:  18 validation loss is  0.12517289817333221 epoch time:  1.155648946762085
#
# Interrupt request received
# epoch:  19 validation loss is  0.12551867961883545 epoch time:  1.1823668479919434
# epoch:  20 validation loss is  0.12413554638624191 epoch time:  1.3358769416809082
# epoch:  21 validation loss is  0.12136930227279663 epoch time:  1.1591520309448242
# epoch:  22 validation loss is  0.12275242805480957 epoch time:  1.1150767803192139
# epoch:  23 validation loss is  0.1220608651638031 epoch time:  1.0489838123321533
# epoch:  24 validation loss is  0.1220608651638031 epoch time:  1.1511609554290771
# epoch:  25 validation loss is  0.12067773938179016 epoch time:  1.3151371479034424
#
#  Currently training PertOpt
#
# Num of cores: 1
# Initial validation loss is  0.32710927724838257
# epoch:  1 validation loss is  0.2627939283847809 epoch time:  4.152620077133179
# epoch:  2 validation loss is  0.1804979294538498 epoch time:  4.1968159675598145

# %%
print(results_train_time)

# %%
print(results_test_loss)

# %%
import matplotlib.pyplot as plt

for idx, model_type in enumerate(models):
    plt.plot(item_values, results_test_loss[idx,:], label=model_type)

plt.title("Best Regret Achieved")
plt.legend()
# plt.savefig('Knapsack_experiment_varying_num_items_regret.pdf')
plt.show()

# %%
for idx, model_type in enumerate(models):
    print(idx, model_type)
    plt.plot(item_values, results_train_time[idx,:], label=model_type)

plt.title("Train Time")
plt.legend()
# plt.savefig('Knapsack_experiment_varying_num_items_train_time.pdf')
plt.show()

# %%
for idx, model_type in enumerate(models):
    print(idx, model_type)
    plt.plot(item_values, results_time_till_best_loss[idx,:], label=model_type)

plt.title("Train Time till Best Model")
plt.legend()
# plt.savefig('Knapsack_experiment_varying_num_items_train_time.pdf')
plt.show()

# %%
print(results_time_till_best_loss)
