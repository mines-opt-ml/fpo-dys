# %%
import numpy as np
from utils import evaluate, plotLearningCurve
import json
from models import WarcraftShortestPathNet
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[9], line 4
#       2 from utils import evaluate, plotLearningCurve
#       3 import json
# ----> 4 from models import WarcraftShortestPathNet
#
# File ~/Research/Implicit-Networks/fpo-dys/src/warcraft/models.py:5
#       3 import cvxpy as cp
#       4 from cvxpylayers.torch import CvxpyLayer
# ----> 5 from src.dys_opt_net import DYS_opt_net
#       6 from pyepo.model.grb import shortestPathModel
#       7 from torchvision.models import resnet18
#
# ModuleNotFoundError: No module named 'src'

# %%
## Load the training statistics
target_file = './results/mse-loss/grid_size_12/DYS.json'
print(target_file)
with open(target_file) as file:
    data = json.load(file)
# Out:
# ./results/mse-loss/grid_size_12/DYS.json

# %%
## Load the model and weights
nnet = WarcraftShortestPathNet
weights_path = './saved_weights/DYS/best.pth'
nnet.load_state_dict(torch.load(path))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 2
#       1 ## Load the model and weights
# ----> 2 nnet = WarcraftShortestPathNet
#       3 weights_path = './saved_weights/DYS/best.pth'
#       4 nnet.load_state_dict(torch.load(path))
#
# NameError: name 'WarcraftShortestPathNet' is not defined

# %%
train_mse_loss_hist = data["train_mse_loss_hist"]
test_regret_hist = data['test_regret_hist']

# %%
plotLearningCurve(train_mse_loss_hist, test_regret_hist, 50)
evaluate()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 plotLearningCurve(train_mse_loss_hist, test_regret_hist, 50)
#
# File ~/Research/Implicit-Networks/fpo-dys/src/warcraft/utils.py:21, in plotLearningCurve(loss_log, regret_log, epochs)
#      19 plt.xticks(fontsize=10)
#      20 plt.yticks(fontsize=10)
# ---> 21 plt.xlim(-epoch/50, epochs+epoch/50)
#      22 plt.ylim(0, max(regret_log[1:])*1.1)
#      23 plt.xlabel("Epochs", fontsize=12)
#
# NameError: name 'epoch' is not defined
